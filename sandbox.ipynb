# %%
import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
name_data = pd.read_csv("firstname_with_sex.csv", sep=";")
df_2 = pd.read_csv("transcriptions_with_sex.csv")

# %%
def extract_groundtruth(df):
    # Créer un ensemble vide pour stocker les noms de colonnes uniques
    unique_columns = set()

    # Parcourir chaque ligne de la colonne "groundtruth"
    for entry in df["groundtruth"]:
        # Utiliser une expression régulière pour extraire les noms de colonnes
        matches = re.findall(r"(\w+):", entry)
        unique_columns.update(matches)

    # Créer des dictionnaires vides pour stocker les données extraites
    extracted_data = {col: [] for col in unique_columns}

    # Parcourir chaque ligne de la colonne "groundtruth" et extraire les données
    for entry in df["groundtruth"]:
        matches = re.findall(r"(\w+): (\w+)", entry)
        entry_data = {col: None for col in unique_columns}
        for match in matches:
            col_name, value = match
            entry_data[col_name] = value
        for col, value in entry_data.items():
            extracted_data[col].append(value)

    # Créer un DataFrame avec les données extraites
    new_df = pd.DataFrame(extracted_data)

    return new_df

# %%
df_2.shape
# Out:
# (241, 4)

# %%
data = df_2.drop("prediction", axis=1)

# %%
new_dataframe = extract_groundtruth(df_2[["groundtruth"]])

# %%
new_dataframe
# Out:
#     civil_status    link occupation observation    lob birth_date   surname  \
# 0           None   fille       idem        None   None       None   Chardon
# 1           None    chef         sp        None   None       None  Lhopital
# 2           None    idem       idem        None   None       None     Papin
# 3           None   femme       None        None  Rigny       1875   Lavocat
# 4           None    None       None        None   None       None     Benne
# ..           ...     ...        ...         ...    ...        ...       ...
# 236         None  épouse       sans        None   None       None  Burlurut
# 237         None     son       idem        None   None       None    Combey
# 238         None  épouse       idem        None   None       None    Collin
# 239         None    fils       None        None   idem       1900    Dumont
# 240         None   belle       None        None  Rigny       1849    Renaut
#
#       age employer   firstname
# 0      30     None       Marie
# 1      67     None       Louis
# 2      15     idem       Marie
# 3    None     None       Marie
# 4      78     None  Marguerite
# ..    ...      ...         ...
# 236    61     None  Pétronille
# 237    39     None   Alexandre
# 238    38     idem  Marguerite
# 239  None     None     Etienne
# 240  None     None  Antoinette
#
# [241 rows x 10 columns]

# %%
for column in new_dataframe.columns:
    print(new_dataframe[column].unique())
# Out:
# [None 'Homme' 'Garçon']
# ['fille' 'chef' 'idem' 'femme' None 'fils' 'enfant' 'Sa' 'enf' 'Chef'
#  'épouse' 'domestique' 'ép' 'père' 'mère' 'Domestique' 'belle' 'Fils'
#  'petite' 'sa' 'Leur' 'petit' 'bru' 'pensionnaire' 'leur' 'mére' 'assisté'
#  'ouvrier' 'frère' 'Schouer' 'Son' 'ch' 'son' 'domest']
# ['idem' 'sp' None 'Métayer' 'néant' 'journalier' 'cantonnier'
#  'Cultivateur' 'sans' 'domestique' 'couvreur' 'roulier' 's' 'cultivateur'
#  'garde' 'journalière' 'manoeuvre' 'forgeron' 'ouvrier' 'propriétaire'
#  'Domestique' 'argentière' 'voiturier' 'jardinier' 'cult' 'métayer'
#  'femme' 'culivateur' 'boulanger' 'buraliste' 'clerc' 'quincaillier'
#  'charcutier' 'sellier' 'Sans' 'imprimeur' 'patissier' 'cullotière'
#  'employé' 'blanchiseuse' 'nourrisson' 'cultivatrice' 'cultivat'
#  'charretier' 'rentière' 'repasseuse' 'receveur' 'Garde' 'domest'
#  'menuisier' 'tourneur' 'agent' 'couturière' 'déposit' 'tisserand'
#  'employée' 'Propriétaire' 'coiffeur' 'cultiv']
# [None 'x']
# [None 'Rigny' 'Paris' 'Saint' 'Coulanges' 'Loire' 'Monétay' 'idem' 'a'
#  'Cher' 'Lunéville' 'Molines' 'm' 'Wlanica' 'Cerny' 'Morbihan' 'Bourbon'
#  'La' 'Vichy' 'St']
# [None '1875' '1835' '1841' '1896' '1885' '1852' '1861' '1904' '1862'
#  '1892' '1899' '1909' '1877' '1847' '1906' '1894' '1888' '1883' '1907'
#  '1922' '1854' '1895' '1908' '1897' '1924' '1891' '1887' '1890' '1898'
#  '1879' '1917' '1863' '1901' '1912' '1857' '1900' '1849']
# ['Chardon' 'Lhopital' 'Papin' 'Lavocat' 'Benne' 'Roy' 'Bizet' 'Garitat'
#  'Souche' 'Guichou' 'Copain' 'Aubouer' 'Raduron' 'Parrot' 'Berger'
#  'Cluzel' 'Daniel' 'Vivier' 'Apied' 'Charrier' 'Martin' 'Mayeur'
#  'Debouesse' 'Quillery' 'Lacroix' 'Schwartz' 'Grillé' 'Berthon' 'idem'
#  'Sauvoisin' 'Thévenin' 'Aumaitre' 'Ursat' 'Philippon' 'Châtel' 'Taravaud'
#  'Bonnet' 'Thomas' 'Sudrot' 'Mazerat' 'Glache' 'Dumont' 'Virmot' 'Giron'
#  'Mallet' 'Coq' 'Pailleret' 'Lognon' 'Vichard' 'Richard' 'Vazelle'
#  'Mangeret' 'Chapelier' 'Gorbinet' 'Grette' 'Daviot' 'Fleury' 'Bonnichon'
#  'Bonnetot' 'Glachet' 'Pénot' 'Grandchamp' 'Joyoz' 'Paturet' 'Laurent'
#  'Lasue' 'Guyon' 'Péronnet' 'Matichard' 'Simonin' 'Forestier' 'Roumeaux'
#  'Brun' 'Régerat' 'Touzelet' 'Rougeron' 'Bouculat' 'Décharne' 'Dumas'
#  'Lécornet' 'Caillot' 'Roumeau' 'Nuret' 'Grobost' 'Demay' 'Parent'
#  'Reynot' 'Prunier' 'Valnaud' 'Pégand' 'Jean' 'Goudin' 'Fayrolle' 'Picot'
#  'Rollin' 'Péron' 'Décluse' 'Thibaut' 'Fabre' 'Aillot' 'Faure' 'Brouant'
#  'Barbier' 'Lahaie' 'Kaermazek' 'Lecornet' 'Ouverkierviez' 'Joubert'
#  'Glomot' 'Coulon' 'Cussinet' 'Le' 'Couyat' 'Gaulme' 'Beraud' 'GAUDIAT'
#  'Ducher' 'Baron' 'Colas' 'Portier' 'Desphelippon' 'Retord' 'Mathion'
#  'Tessin' 'Villeneuve' 'Pasquier' 'Bourdu' 'Gay' 'Vizier' 'Derroziers'
#  'Bonnin' 'Frétier' 'Carte' 'Triboulet' 'Lamouche' 'Decressol' 'Houdes'
#  'Millereux' 'Gaudet' None 'Bauchard' 'Débousset' 'Lavadoune' 'Truffaut'
#  'Terrenoire' 'Journey' 'Lartigaud' 'Tourret' 'Vaclser' 'Loyer' 'Mallais'
#  'Bardot' 'Cotte' 'Bodard' 'Bordet' 'Dey' 'Lécluse' 'Germain' 'Alvire'
#  'Aubouër' 'Boutot' 'Déchery' 'Mély' 'Diry' 'Foury' 'Brulier' 'Lescure'
#  'Gollet' 'Haininger' 'Thély' 'Guignard' 'Belin' 'Auroir' 'Rouchon'
#  'Bazilique' 'Cognet' 'Aufauvre' 'Hameau' 'Mimerel' 'Marmion' 'Choussy'
#  'Autissier' 'Carton' 'RIBET' 'Clayeux' 'Pingeon' 'Guillaumin' 'Conte'
#  'Poussange' 'Burlurut' 'Combey' 'Collin' 'Renaut']
# ['30' '67' '15' None '78' '51' '9' '12' '4' '28' '13' '46' '33' '72' '22'
#  '45' '53' '31' '6' '42' '62' '17' '11' '60' '24' '61' '29' '52' '66' '56'
#  '32' '19' '36' '14' '74' '8' '63' '64' '5' '25' '7' '58' '54' '39' '27'
#  '50' '10' '16' '57' '3' '2' '55' '20' '75' '41' '84' '49' '35' '1' '26'
#  '37' '44' '68' '21' '59' '40' '18' '23' '47' '65' '38']
# [None 'idem' 'néant' 'patron' 'Troussière' 'Bruel' 'Gouvernaire' 'Choussy'
#  'Chabet' 'horticulteur' 'Bonnichou' 'Chene' 'Goudier' 'Lefebure' 'Labage'
#  'Dubuisson' 'Cie' 'Lavocat' 'Margottas' 'Lavany' 'Debord' 'chemin']
# ['Marie' 'Louis' 'Marguerite' 'Antoine' 'Jules' 'Maria' 'Elisabeth'
#  'Jacques' 'Ernestine' 'Anne' 'Annette' 'Jean' 'Gilbert' 'Claude'
#  'Madeleine' 'Alexandre' 'Auguste' 'Rose' 'Nicolas' 'Geneviève' 'Virginie'
#  'Jeanne' 'André' 'Eugènie' 'Joseph' 'Etienne' 'Pierre' 'Josèphine' 'Paul'
#  'Anroine' 'Justine' 'Juliette' 'Clément' 'Léonie' 'Rosalie' 'Claudia'
#  'François' 'Gabriel' 'Suzanne' 'Achille' 'Claudine' 'Marthe' 'Frédéric'
#  'Victor' 'Hélène' 'Henri' 'Albert' 'Joséphine' 'Alphonse' 'Roger' 'Simon'
#  'Antoinette' 'Branislav' 'Emile' 'Stanislas' 'Gervais' None 'Amélie'
#  'Françoise' 'Etiennette' 'Rolland' 'Hippolyte' 'Louise' 'Augustine'
#  'Eugène' 'Thérèse' 'Clémence' 'René' 'Colette' 'Georges' 'Gabrielle'
#  'Mariette' 'Ernest' 'Alix' 'Arthur' 'Antonie' 'Denis' 'France' 'Célina'
#  'Charles' 'Blaise' 'Baptiste' 'Théodore' 'Barthélémy' 'Catherine'
#  'Pétronille']

# %%
for column in new_dataframe.columns:
    data[column] = new_dataframe[column]

# %%
preprocessed_data = data.drop("groundtruth", axis=1)

# %%
preprocessed_data
# Out:
#                              subject_line    sex civil_status    link  \
# 0    ebb26ada-044c-4c62-9dbc-a9c8d505d31c  femme         None   fille
# 1    338496f5-e4ca-43ac-aa5c-429cb3f6ac00  homme         None    chef
# 2    e6a279da-9b6f-4f49-b498-64857bc50d1e  femme         None    idem
# 3    7534deca-39e8-4f00-be17-c12460015de1  femme         None   femme
# 4    ef334a66-a504-418a-9872-e7c9db923488  femme         None    None
# ..                                    ...    ...          ...     ...
# 236  1d92738a-cffe-4aee-ab10-db04c37f7405  femme         None  épouse
# 237  09440055-7972-4135-a537-e6c5a1f2aeb2  homme         None     son
# 238  4d387278-12c3-410c-bdf0-c5c603479764  femme         None  épouse
# 239  623b95de-f87c-4844-a7f7-361088eed83a  homme         None    fils
# 240  26d7839c-16a1-486e-9736-83e500fb72e5  femme         None   belle
#
#     occupation observation    lob birth_date   surname   age employer  \
# 0         idem        None   None       None   Chardon    30     None
# 1           sp        None   None       None  Lhopital    67     None
# 2         idem        None   None       None     Papin    15     idem
# 3         None        None  Rigny       1875   Lavocat  None     None
# 4         None        None   None       None     Benne    78     None
# ..         ...         ...    ...        ...       ...   ...      ...
# 236       sans        None   None       None  Burlurut    61     None
# 237       idem        None   None       None    Combey    39     None
# 238       idem        None   None       None    Collin    38     idem
# 239       None        None   idem       1900    Dumont  None     None
# 240       None        None  Rigny       1849    Renaut  None     None
#
#       firstname
# 0         Marie
# 1         Louis
# 2         Marie
# 3         Marie
# 4    Marguerite
# ..          ...
# 236  Pétronille
# 237   Alexandre
# 238  Marguerite
# 239     Etienne
# 240  Antoinette
#
# [241 rows x 12 columns]

# %%
preprocessed_data.occupation.isna().sum()
# Out:
# 42

# %%
preprocessed_data["firstname"] = preprocessed_data["firstname"].str.lower()

# %%
jointure_data = pd.merge(
    preprocessed_data,
    name_data,
    left_on=["firstname"],
    right_on=["firstname"],
    how="left",
)

# %%
jointure_data.drop("subject_line", axis=1)
# Out:
#        sex civil_status    link occupation observation    lob birth_date  \
# 0    femme         None   fille       idem        None   None       None
# 1    homme         None    chef         sp        None   None       None
# 2    femme         None    idem       idem        None   None       None
# 3    femme         None   femme       None        None  Rigny       1875
# 4    femme         None    None       None        None   None       None
# ..     ...          ...     ...        ...         ...    ...        ...
# 236  femme         None  épouse       sans        None   None       None
# 237  homme         None     son       idem        None   None       None
# 238  femme         None  épouse       idem        None   None       None
# 239  homme         None    fils       None        None   idem       1900
# 240  femme         None   belle       None        None  Rigny       1849
#
#       surname   age employer   firstname      male     female
# 0     Chardon    30     None       marie   10145.0  2390322.0
# 1    Lhopital    67     None       louis  750498.0     2720.0
# 2       Papin    15     idem       marie   10145.0  2390322.0
# 3     Lavocat  None     None       marie   10145.0  2390322.0
# 4       Benne    78     None  marguerite    1441.0   813859.0
# ..        ...   ...      ...         ...       ...        ...
# 236  Burlurut    61     None  pétronille      30.0    13067.0
# 237    Combey    39     None   alexandre   90238.0      413.0
# 238    Collin    38     idem  marguerite    1441.0   813859.0
# 239    Dumont  None     None     etienne  211297.0      898.0
# 240    Renaut  None     None  antoinette     326.0   150155.0
#
# [241 rows x 13 columns]

# %%
texts = [" ".join([str(x) for x in row]) for row in jointure_data]

# %%
jointure_data
# Out:
#                              subject_line    sex civil_status    link  \
# 0    ebb26ada-044c-4c62-9dbc-a9c8d505d31c  femme         None   fille
# 1    338496f5-e4ca-43ac-aa5c-429cb3f6ac00  homme         None    chef
# 2    e6a279da-9b6f-4f49-b498-64857bc50d1e  femme         None    idem
# 3    7534deca-39e8-4f00-be17-c12460015de1  femme         None   femme
# 4    ef334a66-a504-418a-9872-e7c9db923488  femme         None    None
# ..                                    ...    ...          ...     ...
# 236  1d92738a-cffe-4aee-ab10-db04c37f7405  femme         None  épouse
# 237  09440055-7972-4135-a537-e6c5a1f2aeb2  homme         None     son
# 238  4d387278-12c3-410c-bdf0-c5c603479764  femme         None  épouse
# 239  623b95de-f87c-4844-a7f7-361088eed83a  homme         None    fils
# 240  26d7839c-16a1-486e-9736-83e500fb72e5  femme         None   belle
#
#     occupation observation    lob birth_date   surname   age employer  \
# 0         idem        None   None       None   Chardon    30     None
# 1           sp        None   None       None  Lhopital    67     None
# 2         idem        None   None       None     Papin    15     idem
# 3         None        None  Rigny       1875   Lavocat  None     None
# 4         None        None   None       None     Benne    78     None
# ..         ...         ...    ...        ...       ...   ...      ...
# 236       sans        None   None       None  Burlurut    61     None
# 237       idem        None   None       None    Combey    39     None
# 238       idem        None   None       None    Collin    38     idem
# 239       None        None   idem       1900    Dumont  None     None
# 240       None        None  Rigny       1849    Renaut  None     None
#
#       firstname      male     female
# 0         marie   10145.0  2390322.0
# 1         louis  750498.0     2720.0
# 2         marie   10145.0  2390322.0
# 3         marie   10145.0  2390322.0
# 4    marguerite    1441.0   813859.0
# ..          ...       ...        ...
# 236  pétronille      30.0    13067.0
# 237   alexandre   90238.0      413.0
# 238  marguerite    1441.0   813859.0
# 239     etienne  211297.0      898.0
# 240  antoinette     326.0   150155.0
#
# [241 rows x 14 columns]

# %%
df = jointure_data.drop("subject_line", axis=1)

# %%
def concatenate_column_names(row):
    text_parts = []
    for col_name, value in row.iteritems():
        if pd.notna(value) and value != "None":
            text_parts.append(f"{col_name}_{value}")
    return " ".join(text_parts)

# %%
df["texte"] = df.apply(concatenate_row_values_with_column_names, axis=1)
# Out:
# /var/folders/ts/w88f9trn42770xnr2_s8nchh0000gn/T/ipykernel_87459/3371655723.py:3: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, value in row.iteritems():

# %%
df
# Out:
#        sex civil_status    link occupation observation    lob birth_date  \
# 0    femme         None   fille       idem        None   None       None
# 1    homme         None    chef         sp        None   None       None
# 2    femme         None    idem       idem        None   None       None
# 3    femme         None   femme       None        None  Rigny       1875
# 4    femme         None    None       None        None   None       None
# ..     ...          ...     ...        ...         ...    ...        ...
# 236  femme         None  épouse       sans        None   None       None
# 237  homme         None     son       idem        None   None       None
# 238  femme         None  épouse       idem        None   None       None
# 239  homme         None    fils       None        None   idem       1900
# 240  femme         None   belle       None        None  Rigny       1849
#
#       surname   age employer   firstname      male     female  \
# 0     Chardon    30     None       marie   10145.0  2390322.0
# 1    Lhopital    67     None       louis  750498.0     2720.0
# 2       Papin    15     idem       marie   10145.0  2390322.0
# 3     Lavocat  None     None       marie   10145.0  2390322.0
# 4       Benne    78     None  marguerite    1441.0   813859.0
# ..        ...   ...      ...         ...       ...        ...
# 236  Burlurut    61     None  pétronille      30.0    13067.0
# 237    Combey    39     None   alexandre   90238.0      413.0
# 238    Collin    38     idem  marguerite    1441.0   813859.0
# 239    Dumont  None     None     etienne  211297.0      898.0
# 240    Renaut  None     None  antoinette     326.0   150155.0
#
#                                                  texte
# 0    sex_femme link_fille occupation_idem surname_C...
# 1    sex_homme link_chef occupation_sp surname_Lhop...
# 2    sex_femme link_idem occupation_idem surname_Pa...
# 3    sex_femme link_femme lob_Rigny birth_date_1875...
# 4    sex_femme surname_Benne age_78 firstname_margu...
# ..                                                 ...
# 236  sex_femme link_épouse occupation_sans surname_...
# 237  sex_homme link_son occupation_idem surname_Com...
# 238  sex_femme link_épouse occupation_idem surname_...
# 239  sex_homme link_fils lob_idem birth_date_1900 s...
# 240  sex_femme link_belle lob_Rigny birth_date_1849...
#
# [241 rows x 14 columns]

# %%
final_data = jointure_data[["employer","age","birth_date","civil_status","link","occupation","observation","lob","sex"]]

# %%
final_data
# Out:
#     employer   age birth_date civil_status    link occupation observation  \
# 0       None    30       None         None   fille       idem        None
# 1       None    67       None         None    chef         sp        None
# 2       idem    15       None         None    idem       idem        None
# 3       None  None       1875         None   femme       None        None
# 4       None    78       None         None    None       None        None
# ..       ...   ...        ...          ...     ...        ...         ...
# 236     None    61       None         None  épouse       sans        None
# 237     None    39       None         None     son       idem        None
# 238     idem    38       None         None  épouse       idem        None
# 239     None  None       1900         None    fils       None        None
# 240     None  None       1849         None   belle       None        None
#
#        lob    sex
# 0     None  femme
# 1     None  homme
# 2     None  femme
# 3    Rigny  femme
# 4     None  femme
# ..     ...    ...
# 236   None  femme
# 237   None  homme
# 238   None  femme
# 239   idem  homme
# 240  Rigny  femme
#
# [241 rows x 9 columns]

# %%
# Séparation des données en features (X) et target (y)
X = final_data.drop(columns=["sex"])  # Features
y = final_data["sex"]  # Target

# Effectuer un stratified train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# Afficher les tailles des ensembles d'entraînement et de test
print("Taille de l'ensemble d'entraînement :", len(X_train))
print("Taille de l'ensemble de test :", len(X_test))
# Out:
# Taille de l'ensemble d'entraînement : 192
# Taille de l'ensemble de test : 49

# %%
X_train.head(10)
# Out:
# Running cells with 'Python 3.12.0' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
from sklearn.preprocessing import OrdinalEncoder

# Instancier l'encodeur ordinal avec la gestion des inconnus
ordinal_encoder = OrdinalEncoder(
    handle_unknown="use_encoded_value", unknown_value=-1
)

# Appliquer l'encodage ordinal sur les colonnes catégorielles
X_train_encoded = ordinal_encoder.fit_transform(
    X_train[
        [
            "employer",
            "civil_status",
            "link",
            "occupation",
            "observation",
            "lob",
        ]
    ]
)
X_test_encoded = ordinal_encoder.transform(
    X_test[
        [
            "employer",
            "civil_status",
            "link",
            "occupation",
            "observation",
            "lob",
        ]
    ]
)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Instancier le modèle RandomForestClassifier
random_forest = RandomForestClassifier(random_state=42)

# Entraîner le modèle sur X_train_encoded
random_forest.fit(X_train_encoded, y_train)

# Prédire sur X_test_encoded
y_pred = random_forest.predict(X_test_encoded)

# Calculer les métriques
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average="weighted")
conf_matrix = confusion_matrix(y_test, y_pred)

# Afficher les métriques
print("Accuracy:", accuracy)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.7551020408163265
# F1 Score: 0.7573738929534078
# Confusion Matrix:
#  [[ 1  0  1]
#  [ 1 15  6]
#  [ 1  3 21]]

# %%
# Obtenir les modalités de classe prédites par le modèle
class_labels = random_forest.classes_

# Afficher les modalités de classe
print("Classes:", class_labels)
# Out:
# Classes: ['ambigu' 'femme' 'homme']

# %%
from sklearn.preprocessing import LabelEncoder

# Instancier le label encoder
label_encoder = LabelEncoder()

# Fit sur y_train pour obtenir les classes uniques
label_encoder.fit(y_train)

# Transformer y_train et y_test en entiers
y_train_encoded = label_encoder.transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
from xgboost import XGBClassifier

# Instancier le modèle XGBClassifier
xgb_model = XGBClassifier(random_state=42)

# Entraîner le modèle sur X_train_encoded
xgb_model.fit(X_train_encoded, y_train_encoded)

# Prédire sur X_test_encoded
y_pred_xgb = xgb_model.predict(X_test_encoded)

# Obtenir les modalités de classe prédites par le modèle
class_labels_xgb = xgb_model.classes_

# Calculer les métriques
accuracy_xgb = accuracy_score(y_test_encoded, y_pred_xgb)
f1_xgb = f1_score(y_test_encoded, y_pred_xgb, average="weighted")
conf_matrix_xgb = confusion_matrix(y_test_encoded, y_pred_xgb)

# Afficher les métriques
print("Accuracy (XGBoost):", accuracy_xgb)
print("F1 Score (XGBoost):", f1_xgb)
print("Confusion Matrix (XGBoost):\n", conf_matrix_xgb)
print("Classes (XGBoost):", class_labels_xgb)
# Out:
# Accuracy (XGBoost): 0.7551020408163265
# F1 Score (XGBoost): 0.7547357645313072
# Confusion Matrix (XGBoost):
#  [[ 0  0  2]
#  [ 1 16  5]
#  [ 1  3 21]]
# Classes (XGBoost): [0 1 2]

# %%
from sklearn.svm import SVC

# Instancier le modèle SVM
svm_model = SVC(random_state=42)

# Entraîner le modèle sur X_train_encoded
svm_model.fit(X_train_encoded, y_train)

# Prédire sur X_test_encoded
y_pred_svm = svm_model.predict(X_test_encoded)

# Obtenir les modalités de classe prédites par le modèle
class_labels_svm = svm_model.classes_

# Calculer les métriques
accuracy_svm = accuracy_score(y_test, y_pred_svm)
f1_svm = f1_score(y_test, y_pred_svm, average="weighted")
conf_matrix_svm = confusion_matrix(y_test, y_pred_svm)

# Afficher les métriques
print("Accuracy (SVM):", accuracy_svm)
print("F1 Score (SVM):", f1_svm)
print("Confusion Matrix (SVM):\n", conf_matrix_svm)
print("Classes (SVM):", class_labels_svm)
# Out:
# Accuracy (SVM): 0.6326530612244898
# F1 Score (SVM): 0.6153219602696954
# Confusion Matrix (SVM):
#  [[ 0  1  1]
#  [ 0 12 10]
#  [ 0  6 19]]
# Classes (SVM): ['ambigu' 'femme' 'homme']
